# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 3**
# Bases, almacenes y manipulación de datos
#
# ---

# %% [markdown]
# *   NOMBRE: Martin Alejandro Molinero Morales
# *   MATRÍCULA: A01204818

# %% [markdown]
# ---

# %% [markdown]
# En esta actividad usarás la base de datos relacional `classicmodels` (MySQL), compuesta por las siguientes tablas:
#
# *   `Customers`: almacena los datos de los clientes.
# *   `Products`: almacena una lista de modelos de coches a escala.
# *   `ProductLines`: almacena una lista de categorías de líneas de productos.
# *   `Orders`: almacena los pedidos de venta realizados por los clientes.
# *   `OrderDetails`: almacena elementos de línea de pedidos de ventas para cada pedido de ventas.
# *   `Payments`: almacena los pagos realizados por los clientes en función de sus cuentas.
# *   `Employees`: almacena toda la información de los empleados, así como la estructura de la organización, como quién informa a quién.
# *   `Offices`: almacena los datos de la oficina de ventas.
#
# Revisa con detalle su esquema para que comprendas cómo se relacionan las tablas anteriores.

# %% [markdown]
# Recuerda que:
#
#
# *   Una **clave primaria** es un atributo (o conjunto) que identifica unívocamente a cada registro en la tabla.
# *   Una **clave foránea** (externa o ajena) es un atributos (o conjunto) en una tabla que es una clave primaria en otra (o posiblemente la misma) tabla.
# *   Las **relaciones** son las líneas que conectan una tabla con otra y el extremo determina la cardinalidad. Las relaciones con línea continua (identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser foránea y primaria (al mismo tiempo) de otra. Las relaciones con línea discontinua (no identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser sólo foránea en otra.

# %% [markdown]
# # **Parte 1**. SQLAlchemy y SQL básico

# %%
pip install pymysql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import sqlalchemy as sqla
import pymysql
import pandas as pd

# %% [markdown]
# 1.	Crea el motor `sqlalchemy`, con el método `create_engine()` como se muestra a continuación:

# %%
# Crear el motor (dialecto://usuarioBD:clave@ipHostDBMS:puerto/esquema
db = sqla.create_engine('mysql+pymysql://mnaTC4029User:mnaTC4029Pass!@20.106.157.52:3306/classicmodels', pool_recycle=3600)

# %% [markdown]
# Escribe las consultas en SQL para obtener:

# %% [markdown]
# 2.	La información de las líneas de productos.

# %%
pd.read_sql("SELECT * FROM productlines", db)
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %% [markdown]
# 3.	Los empleados ordenados por nombre.

# %%
pd.read_sql("SELECT * FROM employees ORDER BY firstName ASC", db)
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1611     Fixter      Andy      x101
# 1             1143        Bow   Anthony     x5428
# 2             1504      Jones     Barry      x102
# 3             1002     Murphy     Diane     x5800
# 4             1286      Tseng  Foon Yue     x2248
# 5             1323     Vanauf    George     x4102
# 6             1102     Bondur    Gerard     x5408
# 7             1370  Hernandez    Gerard     x2028
# 8             1076   Firrelli      Jeff     x9273
# 9             1188   Firrelli     Julie     x2173
# 10            1501       Bott     Larry     x2311
# 11            1165   Jennings    Leslie     x3291
# 12            1166   Thompson    Leslie     x4065
# 13            1337     Bondur      Loui     x6493
# 14            1621      Nishi      Mami      x101
# 15            1702     Gerard    Martin     x2312
# 16            1056  Patterson      Mary     x4611
# 17            1401   Castillo    Pamela     x2759
# ...

# %% [markdown]
# 4.	Los países donde hay oficinas.

# %%
pd.read_sql("SELECT DISTINCT country FROM offices", db)
# Out:
#      country
# 0        USA
# 1     France
# 2      Japan
# 3  Australia
# 4         UK

# %% [markdown]
# 5.	El nombre y teléfono de los clientes de Nueva York (*NYC*).

# %%
pd.read_sql("SELECT customerName, phone FROM customers where city='NYC'", db)
# Out:
#            customerName       phone
# 0     Land of Toys Inc.  2125557818
# 1    Muscle Machine Inc  2125557413
# 2       Vitachrome Inc.  2125551500
# 3  Classic Legends Inc.  2125558493
# 4       Microscale Inc.  2125551957

# %% [markdown]
# 6.	El código y nombre de los productos del vendedor *Gearbox Collectibles* que tengan menos de 100 unidades en stock.

# %%
pd.read_sql("SELECT productCode, productName FROM products where productVendor='Gearbox Collectibles' AND quantityInStock < 100", db)
# Out:
# Empty DataFrame
# Columns: [productCode, productName]
# Index: []

# %% [markdown]
# 7.	Los tres productos más caros.

# %%
pd.read_sql("SELECT * FROM products ORDER BY buyPrice DESC Limit 3", db)
# Out:
#   productCode                     productName   productLine productScale  \
# 0    S10_4962          1962 LanciaA Delta 16V  Classic Cars         1:10
# 1    S18_2238  1998 Chrysler Plymouth Prowler  Classic Cars         1:18
# 2    S10_1949        1952 Alpine Renault 1300  Classic Cars         1:10
#
#              productVendor                                 productDescription  \
# 0      Second Gear Diecast  Features include: Turnable front wheels; steer...
# 1     Gearbox Collectibles  Turnable front wheels; steering function; deta...
# 2  Classic Metal Creations  Turnable front wheels; steering function; deta...
#
#    quantityInStock  buyPrice    MSRP
# 0             6791    103.42  147.74
# 1             4724    101.51  163.73
# 2             7305     98.58  214.30

# %% [markdown]
# 8.	La cantidad de productos por línea de producto.

# %%
pd.read_sql("SELECT productlines.productLine, COUNT(products.productCode) FROM productlines JOIN products ON products.productLine = productlines.productLine GROUP BY products.productLine", db)
# Out:
#         productLine  COUNT(products.productCode)
# 0      Classic Cars                           38
# 1       Motorcycles                           13
# 2            Planes                           12
# 3             Ships                            9
# 4            Trains                            3
# 5  Trucks and Buses                           11
# 6      Vintage Cars                           24

# %% [markdown]
# 9.	La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).

# %%
pd.read_sql("SELECT offices.country, COUNT(employees.employeeNumber) FROM employees JOIN offices ON offices.officeCode = employees.officeCode GROUP BY offices.country", db)
# Out:
#      country  COUNT(employees.employeeNumber)
# 0  Australia                                4
# 1     France                                5
# 2      Japan                                2
# 3         UK                                2
# 4        USA                               10

# %% [markdown]
# 10.	El promedio de los pagos de los clientes de España.

# %%
pd.read_sql("SELECT AVG(payments.amount) as spain_payment_avg FROM payments JOIN customers ON payments.customerNumber = customers.customerNumber WHERE customers.country='Spain'", db)
# Out:
#    spain_payment_avg
# 0       43236.457826

# %% [markdown]
# # **Parte 2**. Manipulación de datos con Pandas

# %% [markdown]
# 11.	Carga las tablas empleadas en dataframes con el mismo nombre y resuelve las consultas anteriores con las funciones de Pandas. Cuida no sobreescribir los dataframes originales al resolver las consultas. Debes obtener los mismos resultados que con SQL.

# %%
productlines = pd.read_sql("SELECT * FROM productlines", db)
products = pd.read_sql("SELECT * FROM products", db)
orderdetails = pd.read_sql("SELECT * FROM orderdetails", db)
orders = pd.read_sql("SELECT * FROM orders", db)
customers = pd.read_sql("SELECT * FROM customers", db)
employees = pd.read_sql("SELECT * FROM employees", db)
payments = pd.read_sql("SELECT * FROM payments", db)
offices = pd.read_sql("SELECT * FROM offices", db)

# %% [markdown]
# 12.	La información de las líneas de productos.

# %%
productlines
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %% [markdown]
# 13. Los empleados ordenados por nombre.

# %%
employees.sort_values(by='firstName', ascending=True)
# Out:
#     employeeNumber   lastName firstName extension  \
# 17            1611     Fixter      Andy      x101
# 5             1143        Bow   Anthony     x5428
# 16            1504      Jones     Barry      x102
# 0             1002     Murphy     Diane     x5800
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 13            1370  Hernandez    Gerard     x2028
# 4             1102     Bondur    Gerard     x5408
# 2             1076   Firrelli      Jeff     x9273
# 8             1188   Firrelli     Julie     x2173
# 15            1501       Bott     Larry     x2311
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 12            1337     Bondur      Loui     x6493
# 20            1621      Nishi      Mami      x101
# 22            1702     Gerard    Martin     x2312
# 1             1056  Patterson      Mary     x4611
# 14            1401   Castillo    Pamela     x2759
# ...

# %% [markdown]
# 14.	Los países donde hay oficinas.

# %%
offices.country.unique()
# Out:
# array(['USA', 'France', 'Japan', 'Australia', 'UK'], dtype=object)

# %% [markdown]
# 15.	El nombre y teléfono de los clientes de Nueva York (*NYC*).

# %%
nyc_customers = customers.loc[customers['city'] == 'NYC']
nyc_customers[['customerName', 'phone']]
# Out:
#              customerName       phone
# 9       Land of Toys Inc.  2125557818
# 15     Muscle Machine Inc  2125557413
# 27        Vitachrome Inc.  2125551500
# 98   Classic Legends Inc.  2125558493
# 105       Microscale Inc.  2125551957

# %% [markdown]
# 16.	El código y nombre de los productos del vendedor *Gearbox Collectibles* que tengan menos de 100 unidades en stock.

# %%
gearbox_collectibles = products.query('productVendor == "Gearbox Collectibles" & quantityInStock < 100')

gearbox_collectibles[['productCode', 'productName']]
# Out:
# Empty DataFrame
# Columns: [productCode, productName]
# Index: []

# %% [markdown]
# 17.	Los tres productos más caros.

# %%
products.sort_values(by='buyPrice', ascending=False).head(3)
# Out:
#    productCode                     productName   productLine productScale  \
# 5     S10_4962          1962 LanciaA Delta 16V  Classic Cars         1:10
# 25    S18_2238  1998 Chrysler Plymouth Prowler  Classic Cars         1:18
# 1     S10_1949        1952 Alpine Renault 1300  Classic Cars         1:10
#
#               productVendor  \
# 5       Second Gear Diecast
# 25     Gearbox Collectibles
# 1   Classic Metal Creations
#
#                                    productDescription  quantityInStock  \
# 5   Features include: Turnable front wheels; steer...             6791
# 25  Turnable front wheels; steering function; deta...             4724
# 1   Turnable front wheels; steering function; deta...             7305
#
#     buyPrice    MSRP
# 5     103.42  147.74
# 25    101.51  163.73
# 1      98.58  214.30

# %% [markdown]
# 18.	La cantidad de productos por línea de producto.

# %%
products_and_productlines = pd.merge(products, productlines)
products_and_productlines.groupby('productLine')['productCode'].count()
# Out:
# productLine
# Classic Cars        38
# Motorcycles         13
# Planes              12
# Ships                9
# Trains               3
# Trucks and Buses    11
# Vintage Cars        24
# Name: productCode, dtype: int64

# %% [markdown]
# 19.	La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).

# %%
employees_and_offices = pd.merge(offices, employees)
employees_and_offices.groupby('country')['employeeNumber'].count()
# Out:
# country
# Australia     4
# France        5
# Japan         2
# UK            2
# USA          10
# Name: employeeNumber, dtype: int64

# %% [markdown]
# 20.	El promedio de los pagos de los clientes de España.

# %%
payments_and_customers = pd.merge(payments, customers)
payments_in_spain = payments_and_customers.query('country == "Spain"').loc[:, 'amount'].mean()
payments_in_spain
# Out:
# 43236.45782608696

# %% [markdown]
# # **Parte 3**. Cliente de Python Firestore

# %% [markdown]
# En esta fase te conectarás a una base de datos no relacional de Firestore desde Python. Para ello utilizarás los módulos `credentials` y `firestore` de la biblioteca `firebase_admin`.

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# %% [markdown]
# El archivo `veterinary.json` almacena la clave privada para autenticar una cuenta y autorizar el acceso a los servicios de Firebase. A través de la función `Certificate()`, se regresa una credencial inicializada, que puedes utilizar para crear una nueva instancia de la aplicación. Después de eso, tu conexión a Firestore utilizará las reglas de seguridad establecidas para la base de datos y el usuario autenticado.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
DIR = "/content/drive/MyDrive/Maestria/DataScience"
os.chdir(DIR)

# %%
cred = credentials.Certificate('veterinary.json')
firebase_admin.initialize_app(cred)
db = firestore.client()

# %% [markdown]
# 12.	Investiga cómo leer la colección `PET_OWNER` y mostrar su contenido en un dataframe. Asegúrate de incluir el id en el resultado

# %%
doc_ref = db.collection("PET_OWNER")
docs = doc_ref.stream()
docs_dict = list(map(lambda x: {**x.to_dict(),'id': x.id}, docs))
pet_owner_df = pd.DataFrame(docs_dict)
pet_owner_df.set_index('id', inplace=True)
pet_owner_df
# Out:
#                      ownerFirstName ownerLastName         phone  numPets  \
# id
# 0D6yFSs2eu4nYwf2dnQ0            Sam        Taylor  555-454-3465        0
# 98357ufgjmWUxjnAuzbz          Miles         Trent          None        1
# AFtZincSZxjC4Mcxf9Pf            Liz         Frier  555-537-6543        1
# GYDixDwHjMyihjL8TmsM          Jenny      Mayberry  555-454-1243        0
# IpxTuB6FILhwQFcspLws         Marsha         Downs  555-537-8765        2
# QoXBfS1JdRp6BqgLzaAz            Ken       Roberts  555-454-2354        0
# eUtZ44lPRbSHXX04EDp7          Nigel        Melnik  555-232-5678        0
# n2GG9rlfGOmE0P4TcU0T        Richard         James  555-537-7654        3
# pDlJlul8EJXO8FBJvFkN            Jim        Rogers  555-232-3456        0
# tAlJ74xQ7tT4TUHwZgmH           Mary        Keenan  555-232-4567        0
#
#                                             email
# id
# 0D6yFSs2eu4nYwf2dnQ0                         None
# 98357ufgjmWUxjnAuzbz    miles.trent@somewhere.com
# ...

# %%
firebase_admin.delete_app(firebase_admin.get_app())
